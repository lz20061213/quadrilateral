# %%
from coco_text_api import COCO_Text
# %matplotlib inline
import numpy as np
import skimage.io as io
import matplotlib.pyplot as plt
import pylab

result_file = '/home/hezheqi/Project/frame_regression/output/res101/coco_text_test/default/res101_faster_rcnn_iter_150000/detections.pkl'
img_list = '/home/hezheqi/data/coco_text/val/img_list.txt'
image_id = 8848

# %%
ct = COCO_Text('/home/hezheqi/data/coco_text/COCO_Text.json')
dataDir = '/data2/hezheqi/coco'
dataType='train2014'
# Out:
# loading annotations into memory...
# 0:00:06.765009
# creating index...
# index created!

# %%
img = ct.loadImgs(image_id)[0]
pylab.rcParams['figure.figsize'] = (10.0, 8.0)
I = io.imread('%s/images/%s/%s'%(dataDir,dataType,img['file_name']))
print('/images/%s/%s'%(dataType,img['file_name']))
plt.figure()
plt.imshow(I)
# Out:
# /images/train2014/COCO_train2014_000000008848.jpg

# %%
res_path = '/home/hezheqi/Project/frame_regression/output/res101/coco_text_test/default/res101_faster_rcnn_iter_150000/result.json'
our_results = ct.loadRes(res_path)
# Out:
# Loading and preparing results...
# DONE (t=0.49s)

# %%
plt.imshow(I)
annIds = our_results.getAnnIds(image_id)
anns = our_results.loadAnns(annIds)
our_results.showAnns(anns)

# %%
plt.imshow(I)
annIds = ct.getAnnIds(image_id)
anns = ct.loadAnns(annIds)
ct.showAnns(anns)
